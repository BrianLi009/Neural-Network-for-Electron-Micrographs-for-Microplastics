# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate, BatchNormalization, Activation, add
from tensorflow.keras.models import Model, model_from_json
from tensorflow.keras.optimizers import Adam
from keras.layers.advanced_activations import ELU, LeakyReLU
from keras.utils.vis_utils import plot_model
from tensorflow.keras import backend as K 
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from MultiResUNet import *

# %%
def dice_coef(y_true, y_pred):
    smooth = 0.0
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def jacard(y_true, y_pred):

    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum ( y_true_f * y_pred_f)
    union = K.sum ( y_true_f + y_pred_f - y_true_f * y_pred_f)

    return intersection/union

# %%
def saveModel(model):

    model_json = model.to_json()

    try:
        os.makedirs(r'C:\Users\brian\unet_mp(archive)\models')
    except:
        pass
    
    fp = open('models/modelP.json','w')
    fp.write(model_json)
    model.save_weights('models/modelW.h5')

# %%
def evaluateModel(model, X_test, Y_test, batchSize):
    
    try:
        os.makedirs('results')
    except:
        pass 
    

    yp = model.predict(x=X_test, batch_size=batchSize, verbose=1)
    yp = np.round(yp,0)

    for i in range(10):

        plt.figure(figsize=(20,10))
        plt.subplot(1,3,1)
        plt.imshow(X_test[i])
        plt.title('Input')
        plt.subplot(1,3,2)
        plt.imshow(Y_test[i].reshape(Y_test[i].shape[0],Y_test[i].shape[1]))
        plt.title('Ground Truth')
        plt.subplot(1,3,3)
        plt.imshow(yp[i].reshape(yp[i].shape[0],yp[i].shape[1]))
        plt.title('Prediction')

        intersection = yp[i].ravel() * Y_test[i].ravel()
        union = yp[i].ravel() + Y_test[i].ravel() - intersection

        jacard = (np.sum(intersection)/np.sum(union))  
        plt.suptitle('Jacard Index'+ str(np.sum(intersection)) +'/'+ str(np.sum(union)) +'='+str(jacard))

        plt.savefig('results/'+str(i)+'.png',format='png')
        plt.close()


    jacard = 0
    dice = 0
    
    
    for i in range(len(Y_test)):
        yp_2 = yp[i].ravel()
        y2 = Y_test[i].ravel()
        
        intersection = yp_2 * y2
        union = yp_2 + y2 - intersection

        jacard += (np.sum(intersection)/np.sum(union))  

        dice += (2. * np.sum(intersection) ) / (np.sum(yp_2) + np.sum(y2))

    
    jacard /= len(Y_test)
    dice /= len(Y_test)
    


    print('Jacard Index : '+str(jacard))
    print('Dice Coefficient : '+str(dice))
    

    fp = open('models/log.txt','a')
    fp.write(str(jacard)+'\n')
    fp.close()

    fp = open('models/best.txt','r')
    best = fp.read()
    fp.close()

    if(jacard>float(best)):
        print('***********************************************')
        print('Jacard Index improved from '+str(best)+' to '+str(jacard))
        print('***********************************************')
        fp = open('models/best.txt','w')
        fp.write(str(jacard))
        fp.close()

        saveModel(model)

# %%
def trainStep(model, X_train, Y_train, X_test, Y_test, epochs, batchSize):

    
    for epoch in range(epochs):
        print('Epoch : {}'.format(epoch+1))
        model.fit(x=X_train, y=Y_train, batch_size=batchSize, epochs=1, verbose=1)     

        evaluateModel(model,X_test, Y_test,batchSize)

    return model

# %%
img_files = next(os.walk(r'C:\Users\brian\unet_mp(archive)\data\microplastics\data\image'))[2]
msk_files = next(os.walk(r'C:\Users\brian\unet_mp(archive)\data\microplastics\data\mask'))[2]

img_files.sort()
msk_files.sort()


X = []
Y = []

for img_fl in tqdm(img_files):    
    if(img_fl.split('.')[-1]=='png'):
                
        
        img = cv2.imread(r'C:/Users/brian/unet_mp(archive)/data/microplastics/data/image/{}'.format(img_fl), cv2.IMREAD_GRAYSCALE)
        resized_img = cv2.resize(img,(256, 256), interpolation = cv2.INTER_CUBIC)
        
        X.append(resized_img)
        
        msk = cv2.imread(r'C:/Users/brian/unet_mp(archive)/data/microplastics/data/mask/{}'.format(img_fl), cv2.IMREAD_GRAYSCALE)
        resized_msk = cv2.resize(msk,(256, 256), interpolation = cv2.INTER_CUBIC)
        
        Y.append(resized_msk)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 98/98 [00:01<00:00, 68.16it/s]

# %%
print(len(X))
print(len(Y))

X = np.array(X)
Y = np.array(Y)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=3)

Y_train = Y_train.reshape((Y_train.shape[0],Y_train.shape[1],Y_train.shape[2],1))
Y_test = Y_test.reshape((Y_test.shape[0],Y_test.shape[1],Y_test.shape[2],1))

X_train = X_train / 255
X_test = X_test / 255
Y_train = Y_train / 255
Y_test = Y_test / 255

Y_train = np.round(Y_train,0)
Y_test = np.round(Y_test,0)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# 98
# 98
# (88, 256, 256)
# (88, 256, 256, 1)
# (10, 256, 256)
# (10, 256, 256, 1)

# %%
model = MultiResUnet(height=256, width=256, n_channels=1)

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[dice_coef, jacard, 'accuracy'])

saveModel(model)

fp = open('models/log.txt','w')
fp.close()
fp = open('models/best.txt','w')
fp.write('-1.0')
fp.close()
    
trainStep(model, X_train, Y_train, X_test, Y_test, epochs=128, batchSize=1)
#try more epochs and batchsize
# Out:
# C:\Users\brian\anaconda3\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch : 1
# 88/88 [==============================] - 211s 2s/step - loss: 0.5540 - dice_coef: 0.3935 - jacard: 0.2547 - accuracy: 0.8066
# 10/10 [==============================] - 6s 432ms/step
# Jacard Index : 0.0
# Dice Coefficient : 0.0
# ***********************************************
# Jacard Index improved from -1.0 to 0.0
# ***********************************************
# C:\Users\brian\anaconda3\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch : 2
# 88/88 [==============================] - 208s 2s/step - loss: 0.5042 - dice_coef: 0.4153 - jacard: 0.2724 - accuracy: 0.8504
# 10/10 [==============================] - 5s 506ms/step
# Jacard Index : 0.0002984831442193421
# Dice Coefficient : 0.000595361634377858
# ***********************************************
# Jacard Index improved from 0.0 to 0.0002984831442193421
# ***********************************************
# Epoch : 3
# 88/88 [==============================] - 233s 3s/step - loss: 0.4769 - dice_coef: 0.4225 - jacard: 0.2781 - accuracy: 0.8682
# 10/10 [==============================] - 6s 556ms/step
# Jacard Index : 0.0
# Dice Coefficient : 0.0
# Epoch : 4
# 88/88 [==============================] - 287s 3s/step - loss: 0.4520 - dice_coef: 0.4314 - jacard: 0.2853 - accuracy: 0.8775
# 10/10 [==============================] - 7s 675ms/step
# Jacard Index : 0.0011195654542539945
# Dice Coefficient : 0.0022197258988547273
# ***********************************************
# Jacard Index improved from 0.0002984831442193421 to 0.0011195654542539945
# ***********************************************
# Epoch : 5
# 88/88 [==============================] - 283s 3s/step - loss: 0.4346 - dice_coef: 0.4355 - jacard: 0.2885 - accuracy: 0.8880
# 10/10 [==============================] - 6s 634ms/step
# Jacard Index : 0.10705576455213148
# Dice Coefficient : 0.15325290306726086
# ***********************************************
# Jacard Index improved from 0.0011195654542539945 to 0.10705576455213148
# ***********************************************
# Epoch : 6
# 88/88 [==============================] - 255s 3s/step - loss: 0.4106 - dice_coef: 0.4467 - jacard: 0.2980 - accuracy: 0.9020
# 10/10 [==============================] - 6s 567ms/step
# Jacard Index : 0.3173580455043636
# Dice Coefficient : 0.42180409289189813
# ***********************************************
# Jacard Index improved from 0.10705576455213148 to 0.3173580455043636
# ***********************************************
# Epoch : 7
# 88/88 [==============================] - 242s 3s/step - loss: 0.3940 - dice_coef: 0.4517 - jacard: 0.3019 - accuracy: 0.9106
# 10/10 [==============================] - 5s 543ms/step
# Jacard Index : 0.5311852136200008
# Dice Coefficient : 0.6610738938063835
# ***********************************************
# Jacard Index improved from 0.3173580455043636 to 0.5311852136200008
# ***********************************************
# Epoch : 8
# 88/88 [==============================] - 247s 3s/step - loss: 0.3778 - dice_coef: 0.4566 - jacard: 0.3058 - accuracy: 0.9205
# 10/10 [==============================] - 5s 533ms/step
# Jacard Index : 0.4205946327720593
# Dice Coefficient : 0.5417216916055765
# Epoch : 9
# 88/88 [==============================] - 232s 3s/step - loss: 0.3630 - dice_coef: 0.4643 - jacard: 0.3122 - accuracy: 0.9257
# 10/10 [==============================] - 5s 545ms/step
# Jacard Index : 0.47656195668612905
# Dice Coefficient : 0.6172768953526993
# Epoch : 10
# 88/88 [==============================] - 234s 3s/step - loss: 0.3519 - dice_coef: 0.4679 - jacard: 0.3149 - accuracy: 0.9312
# 10/10 [==============================] - 5s 533ms/step
# Jacard Index : 0.5230478345010977
# Dice Coefficient : 0.657668187656369
# Epoch : 11
# 88/88 [==============================] - 233s 3s/step - loss: 0.3375 - dice_coef: 0.4749 - jacard: 0.3209 - accuracy: 0.9393
# 10/10 [==============================] - 5s 530ms/step
# Jacard Index : 0.5775200772887036
# Dice Coefficient : 0.7117653512998289
# ***********************************************
# Jacard Index improved from 0.5311852136200008 to 0.5775200772887036
# ***********************************************
# Epoch : 12
# 88/88 [==============================] - 233s 3s/step - loss: 0.3258 - dice_coef: 0.4808 - jacard: 0.3256 - accuracy: 0.9445
# 10/10 [==============================] - 5s 539ms/step
# Jacard Index : 0.6273547549715704
# Dice Coefficient : 0.7560202562913971
# ***********************************************
# Jacard Index improved from 0.5775200772887036 to 0.6273547549715704
# ***********************************************
# Epoch : 13
# 88/88 [==============================] - 234s 3s/step - loss: 0.3201 - dice_coef: 0.4821 - jacard: 0.3265 - accuracy: 0.9431
# 10/10 [==============================] - 5s 552ms/step
# Jacard Index : 0.5945111401755044
# Dice Coefficient : 0.7341025980413269
# Epoch : 14
# 88/88 [==============================] - 233s 3s/step - loss: 0.3148 - dice_coef: 0.4837 - jacard: 0.3274 - accuracy: 0.9423
# 10/10 [==============================] - 5s 553ms/step
# Jacard Index : 0.5758510735610811
# Dice Coefficient : 0.7217728623942938
# Epoch : 15
# 88/88 [==============================] - 233s 3s/step - loss: 0.3091 - dice_coef: 0.4864 - jacard: 0.3295 - accuracy: 0.9405
# 10/10 [==============================] - 6s 576ms/step
# Jacard Index : 0.48845974619183374
# Dice Coefficient : 0.6200590096388097
# Epoch : 16
# 88/88 [==============================] - 233s 3s/step - loss: 0.2949 - dice_coef: 0.4954 - jacard: 0.3373 - accuracy: 0.9508
# 10/10 [==============================] - 6s 564ms/step
# Jacard Index : 0.5699102615809102
# Dice Coefficient : 0.6910757116056817
# Epoch : 17
# 88/88 [==============================] - 236s 3s/step - loss: 0.2868 - dice_coef: 0.5009 - jacard: 0.3421 - accuracy: 0.9545
# 10/10 [==============================] - 6s 550ms/step
# Jacard Index : 0.6178129615954544
# Dice Coefficient : 0.7346618725354951
# Epoch : 18
# 88/88 [==============================] - 234s 3s/step - loss: 0.2871 - dice_coef: 0.4986 - jacard: 0.3395 - accuracy: 0.9478
# 10/10 [==============================] - 5s 539ms/step
# Jacard Index : 0.5307406252588355
# Dice Coefficient : 0.6516384635235934
# Epoch : 19
# 88/88 [==============================] - 237s 3s/step - loss: 0.2789 - dice_coef: 0.5043 - jacard: 0.3445 - accuracy: 0.9483
# 10/10 [==============================] - 5s 544ms/step
# Jacard Index : 0.6061593610984704
# Dice Coefficient : 0.7298041488398284
# Epoch : 20
# 88/88 [==============================] - 245s 3s/step - loss: 0.2738 - dice_coef: 0.5073 - jacard: 0.3470 - accuracy: 0.9468
# 10/10 [==============================] - 6s 573ms/step
# Jacard Index : 0.5550480687455744
# Dice Coefficient : 0.6895480046265349
# Epoch : 21
# 88/88 [==============================] - 244s 3s/step - loss: 0.2698 - dice_coef: 0.5097 - jacard: 0.3489 - accuracy: 0.9444
# 10/10 [==============================] - 6s 560ms/step
# Jacard Index : 0.6022196599870303
# Dice Coefficient : 0.7214417923765593
# Epoch : 22
# 88/88 [==============================] - 245s 3s/step - loss: 0.2663 - dice_coef: 0.5115 - jacard: 0.3504 - accuracy: 0.9418
# 10/10 [==============================] - 6s 597ms/step
# Jacard Index : 0.5948722072666521
# Dice Coefficient : 0.7135983052709298
# Epoch : 23
# 88/88 [==============================] - 242s 3s/step - loss: 0.2635 - dice_coef: 0.5131 - jacard: 0.3517 - accuracy: 0.9389
# 10/10 [==============================] - 6s 554ms/step
# Jacard Index : 0.5285534856798607
# Dice Coefficient : 0.6605291301649997
# Epoch : 24
# 88/88 [==============================] - 232s 3s/step - loss: 0.2609 - dice_coef: 0.5145 - jacard: 0.3527 - accuracy: 0.9351
# 10/10 [==============================] - 5s 542ms/step
# Jacard Index : 0.595277406593101
# Dice Coefficient : 0.7174473946001428
# Epoch : 25
# 88/88 [==============================] - 229s 3s/step - loss: 0.2598 - dice_coef: 0.5145 - jacard: 0.3526 - accuracy: 0.9327
# 10/10 [==============================] - 5s 548ms/step
# Jacard Index : 0.6035307923118812
# Dice Coefficient : 0.7213092414976952
# Epoch : 26
# 88/88 [==============================] - 236s 3s/step - loss: 0.2576 - dice_coef: 0.5159 - jacard: 0.3536 - accuracy: 0.9286
# 10/10 [==============================] - 5s 547ms/step
# Jacard Index : 0.592909179193292
# Dice Coefficient : 0.716229402202878
# Epoch : 27
# 88/88 [==============================] - 235s 3s/step - loss: 0.2556 - dice_coef: 0.5171 - jacard: 0.3545 - accuracy: 0.9268
# 10/10 [==============================] - 6s 596ms/step
# Jacard Index : 0.5749061410990186
# Dice Coefficient : 0.69734443251084
# Epoch : 28
# 88/88 [==============================] - 238s 3s/step - loss: 0.2539 - dice_coef: 0.5182 - jacard: 0.3555 - accuracy: 0.9254
# 10/10 [==============================] - 6s 562ms/step
# Jacard Index : 0.5831391144696687
# Dice Coefficient : 0.7068208226402609
# Epoch : 29
# 88/88 [==============================] - 236s 3s/step - loss: 0.2527 - dice_coef: 0.5185 - jacard: 0.3556 - accuracy: 0.9250
# 10/10 [==============================] - 5s 551ms/step
# Jacard Index : 0.5723202762952116
# Dice Coefficient : 0.7039850426576655
# Epoch : 30
# 88/88 [==============================] - 238s 3s/step - loss: 0.2554 - dice_coef: 0.5155 - jacard: 0.3526 - accuracy: 0.9202
# 10/10 [==============================] - 6s 559ms/step
# Jacard Index : 0.5481890391118853
# Dice Coefficient : 0.6926834485596091
# Epoch : 31
# 88/88 [==============================] - 237s 3s/step - loss: 0.2735 - dice_coef: 0.4974 - jacard: 0.3360 - accuracy: 0.9083
# 10/10 [==============================] - 5s 550ms/step
# Jacard Index : 0.48971143061295763
# Dice Coefficient : 0.638705917732032
# Epoch : 32
# 88/88 [==============================] - 240s 3s/step - loss: 0.2856 - dice_coef: 0.4852 - jacard: 0.3249 - accuracy: 0.9031
# 10/10 [==============================] - 6s 606ms/step
# Jacard Index : 0.5146263832599933
# Dice Coefficient : 0.6470049725929232
# Epoch : 33
# 88/88 [==============================] - 238s 3s/step - loss: 0.2690 - dice_coef: 0.5000 - jacard: 0.3381 - accuracy: 0.9042
# 10/10 [==============================] - 6s 556ms/step
# Jacard Index : 0.39937806451047325
# Dice Coefficient : 0.5300780844147105
# Epoch : 34
# 88/88 [==============================] - 243s 3s/step - loss: 0.2567 - dice_coef: 0.5119 - jacard: 0.3489 - accuracy: 0.9107
# 10/10 [==============================] - 6s 606ms/step
# Jacard Index : 0.5721875127156097
# Dice Coefficient : 0.6938963419873645
# Epoch : 35
# 88/88 [==============================] - 246s 3s/step - loss: 0.2524 - dice_coef: 0.5161 - jacard: 0.3527 - accuracy: 0.9124
# 10/10 [==============================] - 6s 577ms/step
# Jacard Index : 0.5084907015823854
# Dice Coefficient : 0.6398821841946288
# Epoch : 36
# 88/88 [==============================] - 235s 3s/step - loss: 0.2502 - dice_coef: 0.5181 - jacard: 0.3544 - accuracy: 0.9131
# 10/10 [==============================] - 5s 543ms/step
# Jacard Index : 0.5318914926802247
# Dice Coefficient : 0.6573870880110135
# Epoch : 37
# 88/88 [==============================] - 240s 3s/step - loss: 0.2485 - dice_coef: 0.5193 - jacard: 0.3555 - accuracy: 0.9127
# 10/10 [==============================] - 6s 570ms/step
# Jacard Index : 0.5351571492083441
# Dice Coefficient : 0.6613103042860549
# Epoch : 38
# 88/88 [==============================] - 242s 3s/step - loss: 0.2473 - dice_coef: 0.5204 - jacard: 0.3565 - accuracy: 0.9133
# 10/10 [==============================] - 6s 600ms/step
# Jacard Index : 0.5560684635372144
# Dice Coefficient : 0.6818831922663685
# Epoch : 39
# 88/88 [==============================] - 244s 3s/step - loss: 0.2467 - dice_coef: 0.5208 - jacard: 0.3568 - accuracy: 0.9120
# 10/10 [==============================] - 6s 568ms/step
# Jacard Index : 0.5567776767780441
# Dice Coefficient : 0.6817435585360577
# Epoch : 40
# 88/88 [==============================] - 244s 3s/step - loss: 0.2463 - dice_coef: 0.5211 - jacard: 0.3571 - accuracy: 0.9116
# 10/10 [==============================] - 6s 567ms/step
# Jacard Index : 0.5591432670325307
# Dice Coefficient : 0.6823056407815771
# Epoch : 41
# 88/88 [==============================] - 244s 3s/step - loss: 0.2462 - dice_coef: 0.5211 - jacard: 0.3570 - accuracy: 0.9129
# 10/10 [==============================] - 6s 579ms/step
# Jacard Index : 0.5860585119797919
# Dice Coefficient : 0.7062097883957722
# Epoch : 42
# 88/88 [==============================] - 244s 3s/step - loss: 0.2457 - dice_coef: 0.5214 - jacard: 0.3572 - accuracy: 0.9109
# 10/10 [==============================] - 6s 576ms/step
# Jacard Index : 0.5116385506074366
# Dice Coefficient : 0.6446709611540068
# Epoch : 43
# 88/88 [==============================] - 248s 3s/step - loss: 0.2458 - dice_coef: 0.5211 - jacard: 0.3570 - accuracy: 0.9109
# 10/10 [==============================] - 6s 581ms/step
# Jacard Index : 0.5778654574105813
# Dice Coefficient : 0.7034018070687604
# Epoch : 44
# 88/88 [==============================] - 241s 3s/step - loss: 0.2455 - dice_coef: 0.5212 - jacard: 0.3570 - accuracy: 0.9109
# 10/10 [==============================] - 6s 564ms/step
# Jacard Index : 0.5594652463667422
# Dice Coefficient : 0.6862347366353673
# Epoch : 45
# 88/88 [==============================] - 239s 3s/step - loss: 0.2441 - dice_coef: 0.5227 - jacard: 0.3584 - accuracy: 0.9107
# 10/10 [==============================] - 6s 568ms/step
# Jacard Index : 0.5677775252466742
# Dice Coefficient : 0.6883503636368713
# Epoch : 46
# 88/88 [==============================] - 239s 3s/step - loss: 0.2436 - dice_coef: 0.5232 - jacard: 0.3588 - accuracy: 0.9109
# 10/10 [==============================] - 6s 572ms/step
# Jacard Index : 0.5521710766572746
# Dice Coefficient : 0.6779241092377214
# Epoch : 47
# 88/88 [==============================] - 240s 3s/step - loss: 0.2438 - dice_coef: 0.5228 - jacard: 0.3584 - accuracy: 0.9107
# 10/10 [==============================] - 6s 576ms/step
# Jacard Index : 0.5381135187005684
# Dice Coefficient : 0.6629768604299405
# Epoch : 48
# 88/88 [==============================] - 242s 3s/step - loss: 0.2438 - dice_coef: 0.5227 - jacard: 0.3583 - accuracy: 0.9085
# 10/10 [==============================] - 6s 584ms/step
# Jacard Index : 0.5556955634619566
# Dice Coefficient : 0.6840154840592609
# Epoch : 49
# 88/88 [==============================] - 245s 3s/step - loss: 0.2436 - dice_coef: 0.5227 - jacard: 0.3582 - accuracy: 0.9084
# 10/10 [==============================] - 6s 584ms/step
# Jacard Index : 0.5064242251530542
# Dice Coefficient : 0.6391269119915354
# Epoch : 50
# 88/88 [==============================] - 244s 3s/step - loss: 0.2430 - dice_coef: 0.5234 - jacard: 0.3589 - accuracy: 0.9096
# 10/10 [==============================] - 6s 579ms/step
# Jacard Index : 0.5639462527463571
# Dice Coefficient : 0.6924695567165322
# Epoch : 51
# 88/88 [==============================] - 250s 3s/step - loss: 0.2430 - dice_coef: 0.5233 - jacard: 0.3588 - accuracy: 0.9085
# 10/10 [==============================] - 6s 613ms/step
# Jacard Index : 0.5863088145495949
# Dice Coefficient : 0.7056669424837798
# Epoch : 52
# 88/88 [==============================] - 251s 3s/step - loss: 0.2434 - dice_coef: 0.5229 - jacard: 0.3583 - accuracy: 0.9072
# 10/10 [==============================] - 6s 620ms/step
# Jacard Index : 0.5521564677537061
# Dice Coefficient : 0.6769151424132643
# Epoch : 53
# 88/88 [==============================] - 250s 3s/step - loss: 0.2437 - dice_coef: 0.5226 - jacard: 0.3581 - accuracy: 0.9076
# 10/10 [==============================] - 6s 618ms/step
# Jacard Index : 0.568105454201268
# Dice Coefficient : 0.6939985301401154
# Epoch : 54
# 88/88 [==============================] - 249s 3s/step - loss: 0.2425 - dice_coef: 0.5237 - jacard: 0.3591 - accuracy: 0.9088
# 10/10 [==============================] - 6s 611ms/step
# Jacard Index : 0.5369246723871017
# Dice Coefficient : 0.6626742021108615
# Epoch : 55
# 88/88 [==============================] - 249s 3s/step - loss: 0.2418 - dice_coef: 0.5244 - jacard: 0.3598 - accuracy: 0.9079
# 10/10 [==============================] - 6s 633ms/step
# Jacard Index : 0.5469766758857796
# Dice Coefficient : 0.673792654506012
# Epoch : 56
# 88/88 [==============================] - 251s 3s/step - loss: 0.2415 - dice_coef: 0.5248 - jacard: 0.3602 - accuracy: 0.9083
# 10/10 [==============================] - 6s 629ms/step
# Jacard Index : 0.6063094736167064
# Dice Coefficient : 0.723848534254035
# Epoch : 57
# 88/88 [==============================] - 252s 3s/step - loss: 0.2412 - dice_coef: 0.5250 - jacard: 0.3603 - accuracy: 0.9076
# 10/10 [==============================] - 6s 638ms/step
# Jacard Index : 0.5644853381745658
# Dice Coefficient : 0.690570456823729
# Epoch : 58
# 88/88 [==============================] - 253s 3s/step - loss: 0.2409 - dice_coef: 0.5255 - jacard: 0.3607 - accuracy: 0.9090
# 10/10 [==============================] - 7s 654ms/step
# Jacard Index : 0.57681030809913
# Dice Coefficient : 0.6997409068686908
# Epoch : 59
# 88/88 [==============================] - 254s 3s/step - loss: 0.2414 - dice_coef: 0.5248 - jacard: 0.3601 - accuracy: 0.9081
# 10/10 [==============================] - 6s 640ms/step
# Jacard Index : 0.5671875351331367
# Dice Coefficient : 0.6855572789444183
# Epoch : 60
# 88/88 [==============================] - 253s 3s/step - loss: 0.2408 - dice_coef: 0.5254 - jacard: 0.3607 - accuracy: 0.9084
# 10/10 [==============================] - 6s 633ms/step
# Jacard Index : 0.5931004375248936
# Dice Coefficient : 0.710326737325
# Epoch : 61
# 88/88 [==============================] - 255s 3s/step - loss: 0.2405 - dice_coef: 0.5257 - jacard: 0.3610 - accuracy: 0.9082
# 10/10 [==============================] - 7s 672ms/step
# Jacard Index : 0.5679773179893008
# Dice Coefficient : 0.6962832416484437
# Epoch : 62
# 88/88 [==============================] - 256s 3s/step - loss: 0.2400 - dice_coef: 0.5262 - jacard: 0.3614 - accuracy: 0.9090
# 10/10 [==============================] - 7s 655ms/step
# Jacard Index : 0.5813005531226236
# Dice Coefficient : 0.7028889399827595
# Epoch : 63
# 88/88 [==============================] - 264s 3s/step - loss: 0.2405 - dice_coef: 0.5257 - jacard: 0.3609 - accuracy: 0.9079
# 10/10 [==============================] - 7s 691ms/step
# Jacard Index : 0.5733194575484848
# Dice Coefficient : 0.6922792152372649
# Epoch : 64
# 88/88 [==============================] - 270s 3s/step - loss: 0.2406 - dice_coef: 0.5256 - jacard: 0.3608 - accuracy: 0.9067
# 10/10 [==============================] - 7s 690ms/step
# Jacard Index : 0.5395120847481941
# Dice Coefficient : 0.6735755801106545
# Epoch : 65
# 88/88 [==============================] - 265s 3s/step - loss: 0.2406 - dice_coef: 0.5255 - jacard: 0.3608 - accuracy: 0.9095
# 10/10 [==============================] - 7s 687ms/step
# Jacard Index : 0.5481411201311464
# Dice Coefficient : 0.6722973490118289
# Epoch : 66
# 88/88 [==============================] - 265s 3s/step - loss: 0.2395 - dice_coef: 0.5269 - jacard: 0.3620 - accuracy: 0.9082
# 10/10 [==============================] - 7s 690ms/step
# Jacard Index : 0.5756412603842666
# Dice Coefficient : 0.6980511041971036
# Epoch : 67
# 88/88 [==============================] - 292s 3s/step - loss: 0.2395 - dice_coef: 0.5269 - jacard: 0.3620 - accuracy: 0.9090
# 10/10 [==============================] - 11s 1s/step
# Jacard Index : 0.6009544914898232
# Dice Coefficient : 0.72260319864153
# Epoch : 68
# 88/88 [==============================] - 332s 4s/step - loss: 0.2399 - dice_coef: 0.5267 - jacard: 0.3619 - accuracy: 0.9087
# 10/10 [==============================] - 11s 1s/step
# Jacard Index : 0.5908662729502977
# Dice Coefficient : 0.7241105930116918
# Epoch : 69
# 88/88 [==============================] - 336s 4s/step - loss: 0.2708 - dice_coef: 0.4943 - jacard: 0.3323 - accuracy: 0.8929
# 10/10 [==============================] - 11s 1s/step
# Jacard Index : 0.3338843589227298
# Dice Coefficient : 0.4873667612761228
# Epoch : 70
# 88/88 [==============================] - 341s 4s/step - loss: 0.2760 - dice_coef: 0.4895 - jacard: 0.3278 - accuracy: 0.8899
# 10/10 [==============================] - 11s 1s/step
# Jacard Index : 0.49886046525671013
# Dice Coefficient : 0.6262360028267909
# Epoch : 71
# 88/88 [==============================] - 340s 4s/step - loss: 0.2560 - dice_coef: 0.5085 - jacard: 0.3450 - accuracy: 0.8988
# 10/10 [==============================] - 11s 1s/step
# Jacard Index : 0.3783632603180449
# Dice Coefficient : 0.5057969428318898
# Epoch : 72
# 88/88 [==============================] - 342s 4s/step - loss: 0.2459 - dice_coef: 0.5196 - jacard: 0.3551 - accuracy: 0.9042
# 10/10 [==============================] - 11s 1s/step
# Jacard Index : 0.26477912256997654
# Dice Coefficient : 0.3787425797852052
# Epoch : 73
# 88/88 [==============================] - 344s 4s/step - loss: 0.2424 - dice_coef: 0.5235 - jacard: 0.3589 - accuracy: 0.9062
# 10/10 [==============================] - 11s 1s/step
# Jacard Index : 0.3511910246745594
# Dice Coefficient : 0.4781342907634478
# Epoch : 74
# 88/88 [==============================] - 358s 4s/step - loss: 0.2406 - dice_coef: 0.5255 - jacard: 0.3607 - accuracy: 0.9071
# 10/10 [==============================] - 12s 1s/step
# Jacard Index : 0.44193323584543825
# Dice Coefficient : 0.5743544409499661
# Epoch : 75
# 88/88 [==============================] - 369s 4s/step - loss: 0.2395 - dice_coef: 0.5267 - jacard: 0.3618 - accuracy: 0.9079
# 10/10 [==============================] - 12s 1s/step
# Jacard Index : 0.43475097725092643
# Dice Coefficient : 0.5680881225693876
# Epoch : 76
# 88/88 [==============================] - 361s 4s/step - loss: 0.2388 - dice_coef: 0.5275 - jacard: 0.3626 - accuracy: 0.9082
# 10/10 [==============================] - 12s 1s/step
# Jacard Index : 0.5301129100594487
# Dice Coefficient : 0.6564721284198006
# Epoch : 77
# 88/88 [==============================] - 364s 4s/step - loss: 0.2384 - dice_coef: 0.5278 - jacard: 0.3628 - accuracy: 0.9085
# 10/10 [==============================] - 12s 1s/step
# Jacard Index : 0.5666377422536863
# Dice Coefficient : 0.6885834211477544
# Epoch : 78
# 88/88 [==============================] - 355s 4s/step - loss: 0.2384 - dice_coef: 0.5279 - jacard: 0.3630 - accuracy: 0.9093
# 10/10 [==============================] - 12s 1s/step
# Jacard Index : 0.5967635398785728
# Dice Coefficient : 0.7159064919445272
# Epoch : 79
# 88/88 [==============================] - 359s 4s/step - loss: 0.2386 - dice_coef: 0.5279 - jacard: 0.3630 - accuracy: 0.9099
# 10/10 [==============================] - 12s 1s/step
# Jacard Index : 0.5798062865660379
# Dice Coefficient : 0.6989477783063951
# Epoch : 80
# 88/88 [==============================] - 360s 4s/step - loss: 0.2379 - dice_coef: 0.5285 - jacard: 0.3635 - accuracy: 0.9085
# 10/10 [==============================] - 12s 1s/step
# Jacard Index : 0.5674891901197169
# Dice Coefficient : 0.6885218653433278
# Epoch : 81
# 88/88 [==============================] - 368s 4s/step - loss: 0.2380 - dice_coef: 0.5283 - jacard: 0.3633 - accuracy: 0.9082
# 10/10 [==============================] - 12s 1s/step
# Jacard Index : 0.6030498009285942
# Dice Coefficient : 0.7174575764713259
# Epoch : 82
# 88/88 [==============================] - 374s 4s/step - loss: 0.2378 - dice_coef: 0.5286 - jacard: 0.3636 - accuracy: 0.9093
# 10/10 [==============================] - 13s 1s/step
# Jacard Index : 0.5746469069011433
# Dice Coefficient : 0.692447240215187
# Epoch : 83
# 88/88 [==============================] - 378s 4s/step - loss: 0.2374 - dice_coef: 0.5290 - jacard: 0.3640 - accuracy: 0.9089
# 10/10 [==============================] - 13s 1s/step
# Jacard Index : 0.5771875816443095
# Dice Coefficient : 0.6961513663979731
# Epoch : 84
# 88/88 [==============================] - 378s 4s/step - loss: 0.2378 - dice_coef: 0.5286 - jacard: 0.3636 - accuracy: 0.9072
# 10/10 [==============================] - 14s 1s/step
# Jacard Index : 0.6016395473942672
# Dice Coefficient : 0.7198920369377837
# Epoch : 85
# 88/88 [==============================] - 380s 4s/step - loss: 0.2381 - dice_coef: 0.5282 - jacard: 0.3633 - accuracy: 0.9085
# 10/10 [==============================] - 13s 1s/step
# Jacard Index : 0.6069049367628166
# Dice Coefficient : 0.7241129533728972
# Epoch : 86
# 88/88 [==============================] - 384s 4s/step - loss: 0.2375 - dice_coef: 0.5291 - jacard: 0.3641 - accuracy: 0.9100
# 10/10 [==============================] - 13s 1s/step
# Jacard Index : 0.5938300860329765
# Dice Coefficient : 0.7100350506026499
# Epoch : 87
# 88/88 [==============================] - 383s 4s/step - loss: 0.2372 - dice_coef: 0.5293 - jacard: 0.3642 - accuracy: 0.9082
# 10/10 [==============================] - 13s 1s/step
# Jacard Index : 0.5871347447850601
# Dice Coefficient : 0.7059863539852433
# Epoch : 88
# 88/88 [==============================] - 389s 4s/step - loss: 0.2373 - dice_coef: 0.5292 - jacard: 0.3642 - accuracy: 0.9102
# 10/10 [==============================] - 13s 1s/step
# Jacard Index : 0.59851628169137
# Dice Coefficient : 0.7120897232994154
# Epoch : 89
# 88/88 [==============================] - 393s 4s/step - loss: 0.2369 - dice_coef: 0.5297 - jacard: 0.3646 - accuracy: 0.9090
# 10/10 [==============================] - 13s 1s/step
# Jacard Index : 0.5887498245430194
# Dice Coefficient : 0.7046582248056803
# Epoch : 90
# 88/88 [==============================] - 393s 4s/step - loss: 0.2366 - dice_coef: 0.5298 - jacard: 0.3647 - accuracy: 0.9096
# 10/10 [==============================] - 13s 1s/step
# Jacard Index : 0.5849193166259482
# Dice Coefficient : 0.7027821671605406
# Epoch : 91
# 88/88 [==============================] - 396s 5s/step - loss: 0.2370 - dice_coef: 0.5297 - jacard: 0.3646 - accuracy: 0.9094
# 10/10 [==============================] - 14s 1s/step
# Jacard Index : 0.5968384377825076
# Dice Coefficient : 0.7118175200194311
# Epoch : 92
# 88/88 [==============================] - 398s 5s/step - loss: 0.2369 - dice_coef: 0.5297 - jacard: 0.3646 - accuracy: 0.9080
# 10/10 [==============================] - 14s 1s/step
# Jacard Index : 0.6128262356855583
# Dice Coefficient : 0.7270940600588539
# Epoch : 93
# 88/88 [==============================] - 410s 5s/step - loss: 0.2366 - dice_coef: 0.5300 - jacard: 0.3649 - accuracy: 0.9108
# 10/10 [==============================] - 14s 1s/step
# Jacard Index : 0.5947293221393929
# Dice Coefficient : 0.7092514903039311
# Epoch : 94
# 88/88 [==============================] - 406s 5s/step - loss: 0.2372 - dice_coef: 0.5293 - jacard: 0.3643 - accuracy: 0.9096
# 10/10 [==============================] - 14s 1s/step
# Jacard Index : 0.6040192161656374
# Dice Coefficient : 0.7186633998506129
# Epoch : 95
# 88/88 [==============================] - 409s 5s/step - loss: 0.2368 - dice_coef: 0.5298 - jacard: 0.3647 - accuracy: 0.9086
# 10/10 [==============================] - 14s 1s/step
# Jacard Index : 0.5967116873676102
# Dice Coefficient : 0.7108839296809392
# Epoch : 96
# 88/88 [==============================] - 412s 5s/step - loss: 0.2366 - dice_coef: 0.5301 - jacard: 0.3650 - accuracy: 0.9094
# 10/10 [==============================] - 15s 1s/step
# Jacard Index : 0.6018022567315728
# Dice Coefficient : 0.7167907894165955
# Epoch : 97
# 88/88 [==============================] - 414s 5s/step - loss: 0.2369 - dice_coef: 0.5298 - jacard: 0.3646 - accuracy: 0.9103
# 10/10 [==============================] - 15s 1s/step
# Jacard Index : 0.5885587302979006
# Dice Coefficient : 0.7064268316107257
# Epoch : 98
# 88/88 [==============================] - 484s 6s/step - loss: 0.2367 - dice_coef: 0.5297 - jacard: 0.3646 - accuracy: 0.9102
# 10/10 [==============================] - 15s 1s/step
# Jacard Index : 0.5778621089714273
# Dice Coefficient : 0.6986211808188432
# Epoch : 99
# 88/88 [==============================] - 421s 5s/step - loss: 0.2364 - dice_coef: 0.5303 - jacard: 0.3652 - accuracy: 0.9101
# 10/10 [==============================] - 16s 2s/step
# Jacard Index : 0.6120986845992366
# Dice Coefficient : 0.7246875011476811
# Epoch : 100
# 88/88 [==============================] - 419s 5s/step - loss: 0.2360 - dice_coef: 0.5307 - jacard: 0.3656 - accuracy: 0.9102
# 10/10 [==============================] - 15s 2s/step
# Jacard Index : 0.6162036662190871
# Dice Coefficient : 0.7301059255481064
# Epoch : 101
# 88/88 [==============================] - 433s 5s/step - loss: 0.2360 - dice_coef: 0.5306 - jacard: 0.3654 - accuracy: 0.9092
# 10/10 [==============================] - 17s 2s/step
# Jacard Index : 0.5865060427225373
# Dice Coefficient : 0.7018311328129622
# Epoch : 102
# 88/88 [==============================] - 439s 5s/step - loss: 0.2361 - dice_coef: 0.5307 - jacard: 0.3656 - accuracy: 0.9082
# 10/10 [==============================] - 16s 2s/step
# Jacard Index : 0.6155401175932703
# Dice Coefficient : 0.7302117689979949
# Epoch : 103
# 88/88 [==============================] - 428s 5s/step - loss: 0.2365 - dice_coef: 0.5303 - jacard: 0.3652 - accuracy: 0.9112
# 10/10 [==============================] - 20s 2s/step
# Jacard Index : 0.6034152894095882
# Dice Coefficient : 0.7180536194903733
# Epoch : 104
# 88/88 [==============================] - 453s 5s/step - loss: 0.2361 - dice_coef: 0.5306 - jacard: 0.3655 - accuracy: 0.9105
# 10/10 [==============================] - 16s 2s/step
# Jacard Index : 0.6065934256183213
# Dice Coefficient : 0.7231448293799998
# Epoch : 105
# 88/88 [==============================] - 427s 5s/step - loss: 0.2360 - dice_coef: 0.5306 - jacard: 0.3655 - accuracy: 0.9095
# 10/10 [==============================] - 16s 2s/step
# Jacard Index : 0.5979702854701582
# Dice Coefficient : 0.7125431321193514
# Epoch : 106
# 88/88 [==============================] - 433s 5s/step - loss: 0.2356 - dice_coef: 0.5312 - jacard: 0.3661 - accuracy: 0.9115
# 10/10 [==============================] - 16s 2s/step
# Jacard Index : 0.6119159305878599
# Dice Coefficient : 0.7247554980772539
# Epoch : 107
# 88/88 [==============================] - 438s 5s/step - loss: 0.2360 - dice_coef: 0.5308 - jacard: 0.3656 - accuracy: 0.9099
# 10/10 [==============================] - 16s 2s/step
# Jacard Index : 0.6127108761819494
# Dice Coefficient : 0.7281494966866264
# Epoch : 108
# 88/88 [==============================] - 445s 5s/step - loss: 0.2358 - dice_coef: 0.5309 - jacard: 0.3658 - accuracy: 0.9100
# 10/10 [==============================] - 17s 2s/step
# Jacard Index : 0.6154692276950873
# Dice Coefficient : 0.7282341412438296
# Epoch : 109
# 88/88 [==============================] - 464s 5s/step - loss: 0.2364 - dice_coef: 0.5303 - jacard: 0.3652 - accuracy: 0.9121
# 10/10 [==============================] - 18s 2s/step
# Jacard Index : 0.6143468224377564
# Dice Coefficient : 0.7254145958460253
# Epoch : 110
# 88/88 [==============================] - 473s 5s/step - loss: 0.2360 - dice_coef: 0.5308 - jacard: 0.3656 - accuracy: 0.9076
# 10/10 [==============================] - 17s 2s/step
# Jacard Index : 0.6151777498951448
# Dice Coefficient : 0.7275535313727806
# Epoch : 111
# 88/88 [==============================] - 453s 5s/step - loss: 0.2363 - dice_coef: 0.5304 - jacard: 0.3652 - accuracy: 0.9116
# 10/10 [==============================] - 17s 2s/step
# Jacard Index : 0.6081933011582992
# Dice Coefficient : 0.7217160834484598
# Epoch : 112
# 88/88 [==============================] - 516s 6s/step - loss: 0.2360 - dice_coef: 0.5309 - jacard: 0.3657 - accuracy: 0.9090
# 10/10 [==============================] - 18s 2s/step
# Jacard Index : 0.6071233153423713
# Dice Coefficient : 0.7206755699885518
# Epoch : 113
# 88/88 [==============================] - 506s 6s/step - loss: 0.2354 - dice_coef: 0.5313 - jacard: 0.3662 - accuracy: 0.9118
# 10/10 [==============================] - 18s 2s/step
# Jacard Index : 0.5681203608063805
# Dice Coefficient : 0.684533484100822
# Epoch : 114
# 88/88 [==============================] - 463s 5s/step - loss: 0.2356 - dice_coef: 0.5313 - jacard: 0.3661 - accuracy: 0.9099
# 10/10 [==============================] - 17s 2s/step
# Jacard Index : 0.5862739375830854
# Dice Coefficient : 0.70372803623144
# Epoch : 115
# 88/88 [==============================] - 455s 5s/step - loss: 0.2353 - dice_coef: 0.5316 - jacard: 0.3664 - accuracy: 0.9113
# 10/10 [==============================] - 17s 2s/step
# Jacard Index : 0.6022078943608922
# Dice Coefficient : 0.7138652170886988
# Epoch : 116
# 88/88 [==============================] - 452s 5s/step - loss: 0.2357 - dice_coef: 0.5310 - jacard: 0.3659 - accuracy: 0.9100
# 10/10 [==============================] - 17s 2s/step
# Jacard Index : 0.6419949572922089
# Dice Coefficient : 0.7519492070737915
# ***********************************************
# Jacard Index improved from 0.6273547549715704 to 0.6419949572922089
# ***********************************************
# Epoch : 117
# 88/88 [==============================] - 423s 5s/step - loss: 0.2353 - dice_coef: 0.5315 - jacard: 0.3663 - accuracy: 0.9096
# 10/10 [==============================] - 17s 2s/step
# Jacard Index : 0.610322381206528
# Dice Coefficient : 0.7223968647335869
# Epoch : 118
# 88/88 [==============================] - 434s 5s/step - loss: 0.2349 - dice_coef: 0.5320 - jacard: 0.3668 - accuracy: 0.9113
# 10/10 [==============================] - 17s 2s/step
# Jacard Index : 0.5537158560446638
# Dice Coefficient : 0.6772828944170806
# Epoch : 119
# 88/88 [==============================] - 441s 5s/step - loss: 0.2348 - dice_coef: 0.5320 - jacard: 0.3668 - accuracy: 0.9110
# 10/10 [==============================] - 17s 2s/step
# Jacard Index : 0.5990499833802846
# Dice Coefficient : 0.7114878536784772
# Epoch : 120
# 88/88 [==============================] - 445s 5s/step - loss: 0.2345 - dice_coef: 0.5324 - jacard: 0.3671 - accuracy: 0.9104
# 10/10 [==============================] - 17s 2s/step
# Jacard Index : 0.6017749526227442
# Dice Coefficient : 0.7148127052139526
# Epoch : 121
# 88/88 [==============================] - 449s 5s/step - loss: 0.2342 - dice_coef: 0.5327 - jacard: 0.3675 - accuracy: 0.9112
# 10/10 [==============================] - 17s 2s/step
# Jacard Index : 0.6227474692588896
# Dice Coefficient : 0.7348210184914595
# Epoch : 122
# 88/88 [==============================] - 471s 5s/step - loss: 0.2342 - dice_coef: 0.5329 - jacard: 0.3676 - accuracy: 0.9124
# 10/10 [==============================] - 18s 2s/step
# Jacard Index : 0.6041042485549342
# Dice Coefficient : 0.7153375158125442
# Epoch : 123
# 88/88 [==============================] - 480s 5s/step - loss: 0.2340 - dice_coef: 0.5329 - jacard: 0.3676 - accuracy: 0.9107
# 10/10 [==============================] - 19s 2s/step
# Jacard Index : 0.6101269622839205
# Dice Coefficient : 0.7223555787990473
# Epoch : 124
# 88/88 [==============================] - 483s 5s/step - loss: 0.2341 - dice_coef: 0.5330 - jacard: 0.3677 - accuracy: 0.9116
# 10/10 [==============================] - 19s 2s/step
# Jacard Index : 0.6228136329239267
# Dice Coefficient : 0.7339934374188902
# Epoch : 125
# 88/88 [==============================] - 481s 5s/step - loss: 0.2344 - dice_coef: 0.5326 - jacard: 0.3674 - accuracy: 0.9102
# 10/10 [==============================] - 18s 2s/step
# Jacard Index : 0.6181501400701529
# Dice Coefficient : 0.7291821368418416
# Epoch : 126
# 88/88 [==============================] - 485s 6s/step - loss: 0.2349 - dice_coef: 0.5320 - jacard: 0.3668 - accuracy: 0.9113
# 10/10 [==============================] - 19s 2s/step
# Jacard Index : 0.6161446157541052
# Dice Coefficient : 0.7299644888791351
# Epoch : 127
# 88/88 [==============================] - 495s 6s/step - loss: 0.2356 - dice_coef: 0.5312 - jacard: 0.3661 - accuracy: 0.9112
# 10/10 [==============================] - 19s 2s/step
# Jacard Index : 0.6232624777355495
# Dice Coefficient : 0.7399118788714204
# Epoch : 128
# 88/88 [==============================] - 518s 6s/step - loss: 0.2368 - dice_coef: 0.5300 - jacard: 0.3649 - accuracy: 0.9093
# 10/10 [==============================] - 20s 2s/step
# Jacard Index : 0.5901799659890937
# Dice Coefficient : 0.7074134961251349

# %%
epochs = 5, batchsize = 1
Epoch : 2
88/88 [==============================] - 220s 3s/step - loss: 0.5025 - dice_coef: 0.4151 - jacard: 0.2722 - accuracy: 0.8477
10/10 [==============================] - 5s 540ms/step
Jacard Index : 0.0
Dice Coefficient : 0.0
Epoch : 3
88/88 [==============================] - 219s 2s/step - loss: 0.4699 - dice_coef: 0.4281 - jacard: 0.2831 - accuracy: 0.8752
10/10 [==============================] - 6s 595ms/step
Jacard Index : 0.0
Dice Coefficient : 0.0
Epoch : 4
88/88 [==============================] - 261s 3s/step - loss: 0.4459 - dice_coef: 0.4363 - jacard: 0.2896 - accuracy: 0.8872
10/10 [==============================] - 5s 539ms/step
Jacard Index : 0.023697098506046014
Dice Coefficient : 0.04185880666569874
***********************************************
Jacard Index improved from 0.0 to 0.023697098506046014
***********************************************
Epoch : 5
88/88 [==============================] - 240s 3s/step - loss: 0.4270 - dice_coef: 0.4412 - jacard: 0.2934 - accuracy: 0.8958
10/10 [==============================] - 5s 552ms/step
Jacard Index : 0.27379274573671286
Dice Coefficient : 0.3933915463276028
***********************************************
Jacard Index improved from 0.023697098506046014 to 0.27379274573671286
***********************************************
